# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import pickle

from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.diagnostic import acorr_ljungbox
from scipy import stats
from statsmodels.stats.stattools import jarque_bera

from ta.volatility import BollingerBands
from ta.momentum import RSIIndicator

# %%
df = pd.read_csv('100_stocks_data.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)
df
# Out:
#                Open         High          Low        Close    Volume  \
# 0         40.433960    41.368938    40.204048    41.192673   7564701
# 1         40.464615    41.192673    38.824574    39.138786  17188171
# 2         38.778587    39.246078    37.475750    38.065861  11525782
# 3         37.996887    39.069813    37.506405    38.632977  10660990
# 4         38.832237    39.069813    36.939289    37.084900  11002957
# ...             ...          ...          ...          ...       ...
# 241460  1529.200000  1543.000000  1515.600000  1523.350000    551554
# 241461  1533.900000  1552.900000  1525.400000  1547.250000    516123
# 241462  1547.000000  1559.250000  1540.800000  1555.750000   1224149
# 241463  1560.500000  1561.950000  1525.050000  1537.750000    320652
# 241464  1564.000000  1570.000000  1522.300000  1529.750000   1528204
#
#              Ticker    volume_adi  volume_obv  volume_cmf     volume_fi  ...  \
# 0       ADANIENT.NS  5.275391e+06     7564701         NaN           NaN  ...
# 1       ADANIENT.NS -7.351532e+06    -9623470         NaN           NaN  ...
# 2       ADANIENT.NS -1.119344e+07   -21149252         NaN           NaN  ...
# 3       ADANIENT.NS -6.490088e+06   -10488262         NaN           NaN  ...
# 4       ADANIENT.NS -1.598905e+07   -21491219         NaN           NaN  ...
# ...             ...           ...         ...         ...           ...  ...
# 241460  UNITDSPR.NS -9.265698e+07   435915083    0.150406  8.972093e+06  ...
# 241461  UNITDSPR.NS -9.235293e+07   436431206    0.207457  9.452557e+06  ...
# 241462  UNITDSPR.NS -9.159323e+07   437655355    0.234416  9.588658e+06  ...
# 241463  UNITDSPR.NS -9.169316e+07   437334703    0.206728  7.394316e+06  ...
# 241464  UNITDSPR.NS -9.274401e+07   435806499    0.122338  4.591467e+06  ...
#
#         momentum_ppo  momentum_ppo_signal  momentum_ppo_hist  momentum_pvo  \
# 0                NaN                  NaN                NaN           NaN
# 1                NaN                  NaN                NaN           NaN
# 2                NaN                  NaN                NaN           NaN
# 3                NaN                  NaN                NaN           NaN
# 4                NaN                  NaN                NaN           NaN
# ...              ...                  ...                ...           ...
# 241460      2.228798             2.065220           0.163578    -10.052454
# 241461      2.339432             2.120062           0.219370    -12.031591
# 241462      2.442367             2.184523           0.257843     -6.196572
# 241463      2.398303             2.227279           0.171024    -10.747593
# 241464      2.293578             2.240539           0.053039     -2.081909
#
#         momentum_pvo_signal  momentum_pvo_hist  momentum_kama  others_dr  \
# 0                       NaN                NaN            NaN        NaN
# 1                       NaN                NaN            NaN  -4.986048
# 2                       NaN                NaN            NaN  -2.741336
# 3                       NaN                NaN            NaN   1.489828
# 4                       NaN                NaN            NaN  -4.007138
# ...                     ...                ...            ...        ...
# 241460            -6.487623          -3.564831    1472.924483  -0.382553
# 241461            -7.596416          -4.435175    1479.501082   1.568911
# 241462            -7.316447           1.119875    1488.679001   0.549362
# 241463            -8.002677          -2.744917    1490.797494  -1.156998
# 241464            -6.818523           4.736614    1493.009611  -0.520241
#
#         others_dlr  others_cr
# 0              NaN   0.000000
# 1        -5.114644  -4.986048
# 2        -2.779612  -7.590699
# 3         1.478839  -6.213960
# 4        -4.089635  -9.972096
# ...            ...        ...
# 241460   -0.383287 -41.590460
# 241461    1.556730 -40.674067
# 241462    0.547858 -40.348153
# 241463   -1.163744 -41.038324
# 241464   -0.521599 -41.345066
#
# [241465 rows x 92 columns]

# %%
stock_tickers = df['Ticker'].unique().tolist()

# %%
with open('all_data__list_of_dataframes.pkl', 'rb') as f:
    all_data = pickle.load(f)

# %%
def fill_nan_values(df):
    # Group by 'Ticker' to handle each stock separately
    return df.groupby('Ticker').apply(lambda x: x.fillna(method='bfill').fillna(method='ffill'))

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Ticker', 'volume_adi',
#        'volume_obv', 'volume_cmf', 'volume_fi', 'volume_em', 'volume_sma_em',
#        'volume_vpt', 'volume_vwap', 'volume_mfi', 'volume_nvi',
#        'volatility_bbm', 'volatility_bbh', 'volatility_bbl', 'volatility_bbw',
#        'volatility_bbp', 'volatility_bbhi', 'volatility_bbli',
#        'volatility_kcc', 'volatility_kch', 'volatility_kcl', 'volatility_kcw',
#        'volatility_kcp', 'volatility_kchi', 'volatility_kcli',
#        'volatility_dcl', 'volatility_dch', 'volatility_dcm', 'volatility_dcw',
#        'volatility_dcp', 'volatility_atr', 'volatility_ui', 'trend_macd',
#        'trend_macd_signal', 'trend_macd_diff', 'trend_sma_fast',
#        'trend_sma_slow', 'trend_ema_fast', 'trend_ema_slow',
#        'trend_vortex_ind_pos', 'trend_vortex_ind_neg', 'trend_vortex_ind_diff',
#        'trend_trix', 'trend_mass_index', 'trend_dpo', 'trend_kst',
#        'trend_kst_sig', 'trend_kst_diff', 'trend_ichimoku_conv',
#        'trend_ichimoku_base', 'trend_ichimoku_a', 'trend_ichimoku_b',
#        'trend_stc', 'trend_adx', 'trend_adx_pos', 'trend_adx_neg', 'trend_cci',
#        'trend_visual_ichimoku_a', 'trend_visual_ichimoku_b', 'trend_aroon_up',
#        'trend_aroon_down', 'trend_aroon_ind', 'trend_psar_up',
#        'trend_psar_down', 'trend_psar_up_indicator',
#        'trend_psar_down_indicator', 'momentum_rsi', 'momentum_stoch_rsi',
#        'momentum_stoch_rsi_k', 'momentum_stoch_rsi_d', 'momentum_tsi',
#        'momentum_uo', 'momentum_stoch', 'momentum_stoch_signal', 'momentum_wr',
#        'momentum_ao', 'momentum_roc', 'momentum_ppo', 'momentum_ppo_signal',
#        'momentum_ppo_hist', 'momentum_pvo', 'momentum_pvo_signal',
#        'momentum_pvo_hist', 'momentum_kama', 'others_dr', 'others_dlr',
#        'others_cr'],
#       dtype='object')

# %%
def add_bb_rsi(df, bb_window=20, bb_std=2, rsi_window=14):
    # Bollinger Bands
    bb_indicator = BollingerBands(close=df['Close'], window=bb_window, window_dev=bb_std)
    df['bb_high'] = bb_indicator.bollinger_hband()
    df['bb_low'] = bb_indicator.bollinger_lband()
    df['bb_mid'] = bb_indicator.bollinger_mavg()
    
    # RSI
    rsi_indicator = RSIIndicator(close=df['Close'], window=rsi_window)
    df['rsi'] = rsi_indicator.rsi()
    
    return df

df = add_bb_rsi(df)
df = fill_nan_values(df)

# %%
def calculate_true_range(df):
    df['TR'] = np.maximum(df['High'] - df['Low'], 
                          np.maximum(abs(df['High'] - df['Close'].shift(1)),
                                     abs(df['Low'] - df['Close'].shift(1))))
    return df

def coiled_spring_nr7(df):
    df['ATR'] = df['TR'].rolling(window=7).mean()
    df['NR7'] = df['TR'].rolling(window=7).min() == df['TR']
    
    df['long_signal'] = (df['NR7'] & (df['Close'] > df['bb_mid']) & (df['rsi'] < 50))
    df['short_signal'] = (df['NR7'] & (df['Close'] < df['bb_mid']) & (df['rsi'] > 50))
    
    return df

def finger_finder(df, atr_period=14, atr_multiplier=2):
    df['ATR'] = df['TR'].rolling(window=atr_period).mean()
    df['Upper_Band'] = df['High'].rolling(window=2).max() + (df['ATR'] * atr_multiplier)
    df['Lower_Band'] = df['Low'].rolling(window=2).min() - (df['ATR'] * atr_multiplier)
    
    df['long_signal'] = (df['Close'] > df['Upper_Band'].shift(1)) & (df['rsi'] < 70)
    df['short_signal'] = (df['Close'] < df['Lower_Band'].shift(1)) & (df['rsi'] > 30)
    
    return df

def power_spike(df, volume_threshold=2):
    df['volume_ma'] = df['Volume'].rolling(window=20).mean()
    df['price_change'] = df['Close'] - df['Open']
    
    df['long_signal'] = (df['Volume'] > df['volume_ma'] * volume_threshold) & (df['price_change'] > 0) & (df['rsi'] < 70)
    df['short_signal'] = (df['Volume'] > df['volume_ma'] * volume_threshold) & (df['price_change'] < 0) & (df['rsi'] > 30)
    
    return df

# %%
def backtest_strategy(df, initial_capital=100000, transaction_cost_pct=0.001):
    df['position'] = np.where(df['long_signal'], 1, np.where(df['short_signal'], -1, 0))
    df['position'] = df['position'].fillna(method='ffill')
    
    df['returns'] = df['Close'].pct_change()
    df['strategy_returns'] = df['position'].shift(1) * df['returns'] - abs(df['position'].diff()) * transaction_cost_pct
    
    df['cumulative_returns'] = (1 + df['strategy_returns']).cumprod()
    df['cumulative_strategy'] = initial_capital * df['cumulative_returns']
    
    total_return = df['cumulative_returns'].iloc[-1] - 1
    sharpe_ratio = np.sqrt(252) * df['strategy_returns'].mean() / df['strategy_returns'].std()
    max_drawdown = (df['cumulative_strategy'] / df['cumulative_strategy'].cummax() - 1).min()
    
    return {
        'Total Return': total_return,
        'Sharpe Ratio': sharpe_ratio,
        'Max Drawdown': max_drawdown,
        'Final Portfolio Value': df['cumulative_strategy'].iloc[-1]
    }

def process_stock(df, strategy_func):
    df = add_bb_rsi(df)
    df = calculate_true_range(df)
    df = fill_nan_values(df)
    df = strategy_func(df)
    results = backtest_strategy(df)
    return results

strategies = {
    'Coiled Spring NR7': coiled_spring_nr7,
    'Finger Finder': finger_finder,
    'Power Spike': power_spike
}

# %%
results = {}

for strategy_name, strategy_func in strategies.items():
    strategy_results = {}
    for df in all_data:
        ticker = df['Ticker'].iloc[0]  # Extract the ticker from the DataFrame
        stock_results = process_stock(df, strategy_func)
        strategy_results[ticker] = stock_results
    results[strategy_name] = strategy_results

# Print results
for strategy, stocks in results.items():
    print(f"\nResults for {strategy}:")
    for ticker, performance in stocks.items():
        print(f"{ticker}: {performance}")

# Results converted to dataframe
results_df = pd.DataFrame({(strategy, ticker): performance 
                           for strategy, stocks in results.items() 
                           for ticker, performance in stocks.items()})
print("\nResults DataFrame:")
print(results_df)
# Out:
# Results for Coiled Spring NR7:
# ADANIENT.NS: {'Total Return': -0.10371573181926941, 'Sharpe Ratio': -0.18650802152202975, 'Max Drawdown': -0.17742283911519252, 'Final Portfolio Value': 89628.42681807306}
# ADANIPORTS.NS: {'Total Return': -0.13861850205264448, 'Sharpe Ratio': -0.2909044792510182, 'Max Drawdown': -0.176235689888685, 'Final Portfolio Value': 86138.14979473555}
# APOLLOHOSP.NS: {'Total Return': -0.08499160823852348, 'Sharpe Ratio': -0.22941084847125812, 'Max Drawdown': -0.10865264506338257, 'Final Portfolio Value': 91500.83917614765}
# ASIANPAINT.NS: {'Total Return': -0.15399972059232414, 'Sharpe Ratio': -0.43489992158269913, 'Max Drawdown': -0.17514540954775704, 'Final Portfolio Value': 84600.02794076758}
# AXISBANK.NS: {'Total Return': -0.2706899671329335, 'Sharpe Ratio': -0.7641583228920122, 'Max Drawdown': -0.2975883467525774, 'Final Portfolio Value': 72931.00328670665}
# BAJAJ-AUTO.NS: {'Total Return': 0.011677862283091534, 'Sharpe Ratio': 0.059397448923369935, 'Max Drawdown': -0.053211822665153785, 'Final Portfolio Value': 101167.78622830915}
# BAJFINANCE.NS: {'Total Return': -0.2726081552279669, 'Sharpe Ratio': -0.6815488479077797, 'Max Drawdown': -0.28782265199936086, 'Final Portfolio Value': 72739.18447720331}
# BAJAJFINSV.NS: {'Total Return': -0.04771969636697437, 'Sharpe Ratio': -0.08684729184870457, 'Max Drawdown': -0.16133783500256416, 'Final Portfolio Value': 95228.03036330256}
# BPCL.NS: {'Total Return': -0.05140536434450871, 'Sharpe Ratio': -0.12063607639581254, 'Max Drawdown': -0.0871957070195637, 'Final Portfolio Value': 94859.46356554913}
# BHARTIARTL.NS: {'Total Return': -0.19673217641273055, 'Sharpe Ratio': -0.6465097892225156, 'Max Drawdown': -0.2013559785654523, 'Final Portfolio Value': 80326.78235872694}
# BRITANNIA.NS: {'Total Return': 0.02581515096064191, 'Sharpe Ratio': 0.09917898387853562, 'Max Drawdown': -0.0866728668734954, 'Final Portfolio Value': 102581.51509606419}
# CIPLA.NS: {'Total Return': 0.0010078545371989822, 'Sharpe Ratio': 0.01675090464499701, 'Max Drawdown': -0.06927050238433285, 'Final Portfolio Value': 100100.7854537199}
# COALINDIA.NS: {'Total Return': 0.023145054459271508, 'Sharpe Ratio': 0.07859207553588186, 'Max Drawdown': -0.05983818401256824, 'Final Portfolio Value': 102314.50544592715}
# DIVISLAB.NS: {'Total Return': -0.13094053059857447, 'Sharpe Ratio': -0.46986849610667164, 'Max Drawdown': -0.16793831792975278, 'Final Portfolio Value': 86905.94694014256}
# DRREDDY.NS: {'Total Return': 0.12456454246191617, 'Sharpe Ratio': 0.3136101939360661, 'Max Drawdown': -0.07988141956791606, 'Final Portfolio Value': 112456.45424619161}
# EICHERMOT.NS: {'Total Return': -0.21064677428272605, 'Sharpe Ratio': -0.7102730106843773, 'Max Drawdown': -0.22211936140977528, 'Final Portfolio Value': 78935.32257172739}
# GRASIM.NS: {'Total Return': 0.05052054105877102, 'Sharpe Ratio': 0.19683958659267858, 'Max Drawdown': -0.045873132274975914, 'Final Portfolio Value': 105052.0541058771}
# HCLTECH.NS: {'Total Return': -0.015057716878991823, 'Sharpe Ratio': -0.029764576379556863, 'Max Drawdown': -0.0616683348996766, 'Final Portfolio Value': 98494.22831210082}
# HDFCBANK.NS: {'Total Return': -0.1284397856713263, 'Sharpe Ratio': -0.4864741282474059, 'Max Drawdown': -0.13646907856023582, 'Final Portfolio Value': 87156.02143286738}
# HDFCLIFE.NS: {'Total Return': -0.03588324182697866, 'Sharpe Ratio': -0.120879356486025, 'Max Drawdown': -0.07216710603847654, 'Final Portfolio Value': 96411.67581730214}
# HEROMOTOCO.NS: {'Total Return': -0.045328706259725515, 'Sharpe Ratio': -0.09181647645488374, 'Max Drawdown': -0.09478032269763248, 'Final Portfolio Value': 95467.12937402744}
# HINDALCO.NS: {'Total Return': -0.11965286604125869, 'Sharpe Ratio': -0.20083844616924573, 'Max Drawdown': -0.13641685499116984, 'Final Portfolio Value': 88034.71339587413}
# HINDUNILVR.NS: {'Total Return': -0.09804426034782088, 'Sharpe Ratio': -0.31751989950458187, 'Max Drawdown': -0.14823404818404706, 'Final Portfolio Value': 90195.57396521792}
# ICICIBANK.NS: {'Total Return': -0.13258583430842008, 'Sharpe Ratio': -0.3754487098733427, 'Max Drawdown': -0.14946826292251658, 'Final Portfolio Value': 86741.416569158}
# INDUSINDBK.NS: {'Total Return': -0.3567168178075403, 'Sharpe Ratio': -0.5498967655542397, 'Max Drawdown': -0.3839873497621906, 'Final Portfolio Value': 64328.31821924597}
# INFY.NS: {'Total Return': -0.18020932889169916, 'Sharpe Ratio': -0.5151299898862847, 'Max Drawdown': -0.20792624207877697, 'Final Portfolio Value': 81979.06711083009}
# ITC.NS: {'Total Return': 0.08301768726508496, 'Sharpe Ratio': 0.22603887889170032, 'Max Drawdown': -0.05990370633250641, 'Final Portfolio Value': 108301.7687265085}
# JSWSTEEL.NS: {'Total Return': -0.16442600753351067, 'Sharpe Ratio': -0.4142762753798137, 'Max Drawdown': -0.21623987226264008, 'Final Portfolio Value': 83557.39924664893}
# KOTAKBANK.NS: {'Total Return': -0.027758895316692067, 'Sharpe Ratio': -0.0811367093463641, 'Max Drawdown': -0.09462627274619961, 'Final Portfolio Value': 97224.1104683308}
# LT.NS: {'Total Return': -0.013822093466806629, 'Sharpe Ratio': -0.03768194429333036, 'Max Drawdown': -0.08063492974047792, 'Final Portfolio Value': 98617.79065331933}
# LTIM.NS: {'Total Return': -0.07453821159215823, 'Sharpe Ratio': -0.3325285695493694, 'Max Drawdown': -0.09121755492294659, 'Final Portfolio Value': 92546.17884078418}
# M&M.NS: {'Total Return': -0.031107098959199053, 'Sharpe Ratio': -0.07553026023596808, 'Max Drawdown': -0.12734754634571321, 'Final Portfolio Value': 96889.2901040801}
# MARUTI.NS: {'Total Return': -0.03784784543825537, 'Sharpe Ratio': -0.07745810703886649, 'Max Drawdown': -0.08485633528189329, 'Final Portfolio Value': 96215.21545617447}
# NESTLEIND.NS: {'Total Return': -0.10583197687480961, 'Sharpe Ratio': -0.5516250665302609, 'Max Drawdown': -0.1442955754541001, 'Final Portfolio Value': 89416.80231251904}
# NTPC.NS: {'Total Return': -0.09694232842083672, 'Sharpe Ratio': -0.5499288775759048, 'Max Drawdown': -0.11491471548994447, 'Final Portfolio Value': 90305.76715791633}
# ONGC.NS: {'Total Return': -0.17941588235501393, 'Sharpe Ratio': -0.38516394844642565, 'Max Drawdown': -0.24766287086989336, 'Final Portfolio Value': 82058.41176449861}
# POWERGRID.NS: {'Total Return': 0.029854872045584235, 'Sharpe Ratio': 0.10945677632126938, 'Max Drawdown': -0.06428473408073465, 'Final Portfolio Value': 102985.48720455842}
# RELIANCE.NS: {'Total Return': 0.02932161006903322, 'Sharpe Ratio': 0.09527712491270568, 'Max Drawdown': -0.10066876153654014, 'Final Portfolio Value': 102932.16100690332}
# SBILIFE.NS: {'Total Return': 0.042943375624045155, 'Sharpe Ratio': 0.20455098445873088, 'Max Drawdown': -0.058015691644134226, 'Final Portfolio Value': 104294.33756240451}
# SHRIRAMFIN.NS: {'Total Return': 0.38718511964366864, 'Sharpe Ratio': 0.4047147538299912, 'Max Drawdown': -0.13090945049130265, 'Final Portfolio Value': 138718.51196436686}
# SBIN.NS: {'Total Return': -0.06644999206541236, 'Sharpe Ratio': -0.23431189005063413, 'Max Drawdown': -0.07931875532043176, 'Final Portfolio Value': 93355.00079345876}
# SUNPHARMA.NS: {'Total Return': 0.03663535594436418, 'Sharpe Ratio': 0.11820507558497459, 'Max Drawdown': -0.04281772193624467, 'Final Portfolio Value': 103663.53559443641}
# TCS.NS: {'Total Return': -0.03658086351140233, 'Sharpe Ratio': -0.11020658108512067, 'Max Drawdown': -0.13902724564702496, 'Final Portfolio Value': 96341.91364885977}
# TATACONSUM.NS: {'Total Return': -0.006411481980244105, 'Sharpe Ratio': 0.007913173022133102, 'Max Drawdown': -0.14821957529567953, 'Final Portfolio Value': 99358.85180197559}
# TATAMOTORS.NS: {'Total Return': 0.14861173852103193, 'Sharpe Ratio': 0.24733092156992906, 'Max Drawdown': -0.09860378079893894, 'Final Portfolio Value': 114861.1738521032}
# TATASTEEL.NS: {'Total Return': -0.47545341427485666, 'Sharpe Ratio': -1.0379146652981095, 'Max Drawdown': -0.47545341427485666, 'Final Portfolio Value': 52454.65857251434}
# TECHM.NS: {'Total Return': 0.14591943136853747, 'Sharpe Ratio': 0.4369898155275715, 'Max Drawdown': -0.042835409536762015, 'Final Portfolio Value': 114591.94313685375}
# TITAN.NS: {'Total Return': -0.13713704023670692, 'Sharpe Ratio': -0.4039662156706601, 'Max Drawdown': -0.16744119171243266, 'Final Portfolio Value': 86286.2959763293}
# ULTRACEMCO.NS: {'Total Return': -0.024383250257141498, 'Sharpe Ratio': -0.06219189486192686, 'Max Drawdown': -0.09640530834548344, 'Final Portfolio Value': 97561.67497428585}
# WIPRO.NS: {'Total Return': 0.043925548941478265, 'Sharpe Ratio': 0.17469968537084954, 'Max Drawdown': -0.06295245300177243, 'Final Portfolio Value': 104392.55489414783}
# ABB.NS: {'Total Return': -0.16319974906421908, 'Sharpe Ratio': -0.4813640272926672, 'Max Drawdown': -0.1880443349887838, 'Final Portfolio Value': 83680.0250935781}
# ADANIENSOL.NS: {'Total Return': 0.02083574293461754, 'Sharpe Ratio': 0.7755878787878646, 'Max Drawdown': -0.009111268477284273, 'Final Portfolio Value': 102083.57429346176}
# ADANIGREEN.NS: {'Total Return': 0.47491457204209886, 'Sharpe Ratio': 0.8107093590727836, 'Max Drawdown': -0.05270265517936712, 'Final Portfolio Value': 147491.45720420987}
# ADANIPOWER.NS: {'Total Return': -0.11047683946893205, 'Sharpe Ratio': -0.19007187869134387, 'Max Drawdown': -0.2001113901005891, 'Final Portfolio Value': 88952.3160531068}
# ATGL.NS: {'Total Return': -0.09591247260144631, 'Sharpe Ratio': -0.2558920554181947, 'Max Drawdown': -0.14327840703933148, 'Final Portfolio Value': 90408.75273985536}
# AMBUJACEM.NS: {'Total Return': -0.26332517352393847, 'Sharpe Ratio': -0.9620925114252762, 'Max Drawdown': -0.26767580959105175, 'Final Portfolio Value': 73667.48264760616}
# BAJAJHLDNG.NS: {'Total Return': -0.23974132000014348, 'Sharpe Ratio': -0.6697055005338856, 'Max Drawdown': -0.2630870742471507, 'Final Portfolio Value': 76025.86799998565}
# BANKBARODA.NS: {'Total Return': -0.08002012423075022, 'Sharpe Ratio': -0.10157772270255065, 'Max Drawdown': -0.14138010120138123, 'Final Portfolio Value': 91997.98757692498}
# BERGEPAINT.NS: {'Total Return': -0.20138977154862625, 'Sharpe Ratio': -0.513784864506685, 'Max Drawdown': -0.23147206232661566, 'Final Portfolio Value': 79861.02284513737}
# BEL.NS: {'Total Return': 0.1542038222050517, 'Sharpe Ratio': 0.37683658782470186, 'Max Drawdown': -0.05046453457516398, 'Final Portfolio Value': 115420.38222050517}
# BOSCHLTD.NS: {'Total Return': -0.13069502942175337, 'Sharpe Ratio': -0.26077631624918873, 'Max Drawdown': -0.2562594394823787, 'Final Portfolio Value': 86930.49705782466}
# CANBK.NS: {'Total Return': -0.0317532848234785, 'Sharpe Ratio': -0.05863528897808973, 'Max Drawdown': -0.08957716833314089, 'Final Portfolio Value': 96824.67151765215}
# CHOLAFIN.NS: {'Total Return': -0.2805911997369325, 'Sharpe Ratio': -0.6125452047068011, 'Max Drawdown': -0.31611777915666495, 'Final Portfolio Value': 71940.88002630675}
# COLPAL.NS: {'Total Return': -0.10225789716536204, 'Sharpe Ratio': -0.43888634988865355, 'Max Drawdown': -0.11747750880044106, 'Final Portfolio Value': 89774.21028346379}
# DABUR.NS: {'Total Return': -0.18661117919477688, 'Sharpe Ratio': -0.6722655480304077, 'Max Drawdown': -0.21038577059159647, 'Final Portfolio Value': 81338.88208052231}
# DLF.NS: {'Total Return': 0.001966668626554924, 'Sharpe Ratio': 0.03252423710600231, 'Max Drawdown': -0.1189257119112368, 'Final Portfolio Value': 100196.66686265549}
# DMART.NS: {'Total Return': -0.08500900144063717, 'Sharpe Ratio': -0.3325297501687223, 'Max Drawdown': -0.09749042135153851, 'Final Portfolio Value': 91499.09985593628}
# GAIL.NS: {'Total Return': -0.14994320766818803, 'Sharpe Ratio': -0.4031734641567956, 'Max Drawdown': -0.15105258119561982, 'Final Portfolio Value': 85005.6792331812}
# GODREJCP.NS: {'Total Return': -0.09897197149750858, 'Sharpe Ratio': -0.2836349204141199, 'Max Drawdown': -0.10220439504403689, 'Final Portfolio Value': 90102.80285024914}
# HAVELLS.NS: {'Total Return': -0.18489214909513885, 'Sharpe Ratio': -0.5180775142156587, 'Max Drawdown': -0.18489214909513885, 'Final Portfolio Value': 81510.78509048611}
# HAL.NS: {'Total Return': 0.013392993531399222, 'Sharpe Ratio': 0.0830005746497277, 'Max Drawdown': -0.07794878093342372, 'Final Portfolio Value': 101339.29935313993}
# ICICIGI.NS: {'Total Return': -0.04382837721240229, 'Sharpe Ratio': -0.24585454908971366, 'Max Drawdown': -0.12258917645560286, 'Final Portfolio Value': 95617.16227875977}
# ICICIPRULI.NS: {'Total Return': -0.10827714204088656, 'Sharpe Ratio': -0.338879302367221, 'Max Drawdown': -0.1597480104461788, 'Final Portfolio Value': 89172.28579591135}
# IOC.NS: {'Total Return': -0.06822799839488847, 'Sharpe Ratio': -0.10473390761715404, 'Max Drawdown': -0.12281658253077954, 'Final Portfolio Value': 93177.20016051116}
# INDIGO.NS: {'Total Return': -0.04076186116934788, 'Sharpe Ratio': -0.07749912194936326, 'Max Drawdown': -0.12636549242027406, 'Final Portfolio Value': 95923.81388306522}
# NAUKRI.NS: {'Total Return': -0.13648791589909426, 'Sharpe Ratio': -0.3173394588445099, 'Max Drawdown': -0.19377300296425493, 'Final Portfolio Value': 86351.20841009058}
# IRCTC.NS: {'Total Return': -0.13713248542314693, 'Sharpe Ratio': -0.7231234917680345, 'Max Drawdown': -0.13713248542314682, 'Final Portfolio Value': 86286.75145768531}
# IRFC.NS: {'Total Return': 0.004311481757321101, 'Sharpe Ratio': 0.052091700702314725, 'Max Drawdown': -0.04990406645792245, 'Final Portfolio Value': 100431.14817573212}
# JINDALSTEL.NS: {'Total Return': -0.22208071305101096, 'Sharpe Ratio': -0.3884623151799141, 'Max Drawdown': -0.3002489537556018, 'Final Portfolio Value': 77791.9286948989}
# JIOFIN.NS: {'Total Return': -0.07477297944244155, 'Sharpe Ratio': -2.039393329631456, 'Max Drawdown': -0.07477297944244155, 'Final Portfolio Value': 92522.70205575584}
# LICI.NS: {'Total Return': -0.01858891975473287, 'Sharpe Ratio': -0.37583551320687036, 'Max Drawdown': -0.04651670829563548, 'Final Portfolio Value': 98141.10802452671}
# MARICO.NS: {'Total Return': -0.18555580280733475, 'Sharpe Ratio': -0.5276410070201009, 'Max Drawdown': -0.22799783126803363, 'Final Portfolio Value': 81444.41971926653}
# PIDILITIND.NS: {'Total Return': 0.010822338587570757, 'Sharpe Ratio': 0.05084485053614371, 'Max Drawdown': -0.059405390321245255, 'Final Portfolio Value': 101082.23385875707}
# PFC.NS: {'Total Return': -0.2200354590038066, 'Sharpe Ratio': -0.5773544539526948, 'Max Drawdown': -0.22329329976602896, 'Final Portfolio Value': 77996.45409961934}
# PNB.NS: {'Total Return': -0.11659670315827764, 'Sharpe Ratio': -0.2572782973705867, 'Max Drawdown': -0.1980547595792328, 'Final Portfolio Value': 88340.32968417223}
# RECLTD.NS: {'Total Return': 0.0829588427650183, 'Sharpe Ratio': 0.20353911121309887, 'Max Drawdown': -0.11202031942735657, 'Final Portfolio Value': 108295.88427650183}
# MOTHERSON.NS: {'Total Return': -0.12539688541369398, 'Sharpe Ratio': -0.25346137166675664, 'Max Drawdown': -0.1388414656994954, 'Final Portfolio Value': 87460.3114586306}
# SBICARD.NS: {'Total Return': -0.13127230465424022, 'Sharpe Ratio': -0.8773399458792521, 'Max Drawdown': -0.14466657553826212, 'Final Portfolio Value': 86872.76953457597}
# SHREECEM.NS: {'Total Return': -0.14023392056330475, 'Sharpe Ratio': -0.4475036683184448, 'Max Drawdown': -0.15630137547710854, 'Final Portfolio Value': 85976.60794366953}
# SIEMENS.NS: {'Total Return': -0.13408379799873393, 'Sharpe Ratio': -0.5806312319129316, 'Max Drawdown': -0.14012810987768176, 'Final Portfolio Value': 86591.6202001266}
# SRF.NS: {'Total Return': -0.12711701674600717, 'Sharpe Ratio': -0.33497237720946416, 'Max Drawdown': -0.18186863210598947, 'Final Portfolio Value': 87288.29832539929}
# TATAPOWER.NS: {'Total Return': -0.08382718872353223, 'Sharpe Ratio': -0.22788852464815695, 'Max Drawdown': -0.12428568968468579, 'Final Portfolio Value': 91617.28112764678}
# TORNTPHARM.NS: {'Total Return': -0.16027771995149986, 'Sharpe Ratio': -0.49105408022907476, 'Max Drawdown': -0.1921136595946653, 'Final Portfolio Value': 83972.22800485001}
# TRENT.NS: {'Total Return': -0.13986182943295722, 'Sharpe Ratio': -0.3136719855029349, 'Max Drawdown': -0.16521181965482978, 'Final Portfolio Value': 86013.81705670428}
# TVSMOTOR.NS: {'Total Return': -0.15956738711582996, 'Sharpe Ratio': -0.2567349399366391, 'Max Drawdown': -0.17047525744570824, 'Final Portfolio Value': 84043.26128841701}
# VBL.NS: {'Total Return': -0.05183803589908087, 'Sharpe Ratio': -0.08452562568887852, 'Max Drawdown': -0.21305889012517765, 'Final Portfolio Value': 94816.19641009191}
# VEDL.NS: {'Total Return': -0.2899655676259987, 'Sharpe Ratio': -0.6031906352772979, 'Max Drawdown': -0.29525957472440456, 'Final Portfolio Value': 71003.44323740013}
# ZOMATO.NS: {'Total Return': 0.11157428460878638, 'Sharpe Ratio': 0.39380443789505626, 'Max Drawdown': -0.06882088412140164, 'Final Portfolio Value': 111157.42846087864}
# ZYDUSLIFE.NS: {'Total Return': -0.13840846343754076, 'Sharpe Ratio': -0.5144358132647114, 'Max Drawdown': -0.16345808884066393, 'Final Portfolio Value': 86159.15365624592}
# UNITDSPR.NS: {'Total Return': -0.09438984789584282, 'Sharpe Ratio': -0.23121206659504545, 'Max Drawdown': -0.15437122310176632, 'Final Portfolio Value': 90561.01521041572}
#
# Results for Finger Finder:
# ADANIENT.NS: {'Total Return': 0.06531449660914523, 'Sharpe Ratio': 0.2405773549482245, 'Max Drawdown': -0.033912381475627584, 'Final Portfolio Value': 106531.44966091453}
# ADANIPORTS.NS: {'Total Return': -0.15716768453014385, 'Sharpe Ratio': -0.43073687694907614, 'Max Drawdown': -0.1891193444015803, 'Final Portfolio Value': 84283.23154698561}
# APOLLOHOSP.NS: {'Total Return': 0.0504316886558831, 'Sharpe Ratio': 0.23518269949670556, 'Max Drawdown': -0.03743142114126674, 'Final Portfolio Value': 105043.1688655883}
# ASIANPAINT.NS: {'Total Return': 0.07381880459288936, 'Sharpe Ratio': 0.2939311683522483, 'Max Drawdown': -0.002738153160098622, 'Final Portfolio Value': 107381.88045928894}
# AXISBANK.NS: {'Total Return': 0.030142512772404872, 'Sharpe Ratio': 0.16728236504556745, 'Max Drawdown': -0.04353158143481417, 'Final Portfolio Value': 103014.25127724049}
# BAJAJ-AUTO.NS: {'Total Return': 0.05117261930964068, 'Sharpe Ratio': 0.29082976103482966, 'Max Drawdown': -0.008850861622492934, 'Final Portfolio Value': 105117.26193096407}
# BAJFINANCE.NS: {'Total Return': -0.033129207145881856, 'Sharpe Ratio': -0.0682587252354793, 'Max Drawdown': -0.11996126947390195, 'Final Portfolio Value': 96687.07928541182}
# BAJAJFINSV.NS: {'Total Return': -0.011161229403869877, 'Sharpe Ratio': -0.024686479558126, 'Max Drawdown': -0.046566717010069314, 'Final Portfolio Value': 98883.877059613}
# BPCL.NS: {'Total Return': 0.03922768055110004, 'Sharpe Ratio': 0.21292266076213165, 'Max Drawdown': -0.024021402665714175, 'Final Portfolio Value': 103922.76805511}
# BHARTIARTL.NS: {'Total Return': 0.011770866097547295, 'Sharpe Ratio': 0.051558662244349754, 'Max Drawdown': -0.0696033323835824, 'Final Portfolio Value': 101177.08660975473}
# BRITANNIA.NS: {'Total Return': 0.13954429314435757, 'Sharpe Ratio': 0.5129721448571584, 'Max Drawdown': -0.0010000000000000009, 'Final Portfolio Value': 113954.42931443575}
# CIPLA.NS: {'Total Return': 0.05466976174239546, 'Sharpe Ratio': 0.23712395377179488, 'Max Drawdown': -0.04444908068896525, 'Final Portfolio Value': 105466.97617423955}
# COALINDIA.NS: {'Total Return': -0.047487901183644765, 'Sharpe Ratio': -0.1843190821313055, 'Max Drawdown': -0.0704560627003018, 'Final Portfolio Value': 95251.20988163553}
# DIVISLAB.NS: {'Total Return': 0.04209888816089791, 'Sharpe Ratio': 0.16489725669105468, 'Max Drawdown': -0.054808624158764085, 'Final Portfolio Value': 104209.88881608979}
# DRREDDY.NS: {'Total Return': -0.0019428265306811188, 'Sharpe Ratio': -6.370032223819951e-06, 'Max Drawdown': -0.06147391606025465, 'Final Portfolio Value': 99805.7173469319}
# EICHERMOT.NS: {'Total Return': 0.18017563047140106, 'Sharpe Ratio': 0.5287651747121115, 'Max Drawdown': -0.009089003802845386, 'Final Portfolio Value': 118017.56304714011}
# GRASIM.NS: {'Total Return': 0.015459961657147137, 'Sharpe Ratio': 0.07668565003505542, 'Max Drawdown': -0.05311759908621505, 'Final Portfolio Value': 101545.9961657147}
# HCLTECH.NS: {'Total Return': -0.0041405049000535765, 'Sharpe Ratio': -0.17832167073809824, 'Max Drawdown': -0.008179844756584842, 'Final Portfolio Value': 99585.94950999464}
# HDFCBANK.NS: {'Total Return': 0.13749936533187146, 'Sharpe Ratio': 0.5349674659573698, 'Max Drawdown': -0.014538443144649804, 'Final Portfolio Value': 113749.93653318715}
# HDFCLIFE.NS: {'Total Return': 0.02561697036663313, 'Sharpe Ratio': 0.41318986145825487, 'Max Drawdown': -0.001000000000000112, 'Final Portfolio Value': 102561.69703666332}
# HEROMOTOCO.NS: {'Total Return': -0.006007797485345967, 'Sharpe Ratio': -0.06012060040382742, 'Max Drawdown': -0.032937717267761624, 'Final Portfolio Value': 99399.2202514654}
# HINDALCO.NS: {'Total Return': 0.02076474417715457, 'Sharpe Ratio': 0.19470108220535506, 'Max Drawdown': -0.02000229886931648, 'Final Portfolio Value': 102076.47441771545}
# HINDUNILVR.NS: {'Total Return': 0.014044649720680757, 'Sharpe Ratio': 0.1018610055207356, 'Max Drawdown': -0.026495103666550612, 'Final Portfolio Value': 101404.46497206808}
# ICICIBANK.NS: {'Total Return': -0.058005852980410055, 'Sharpe Ratio': -0.6406155070236967, 'Max Drawdown': -0.060480285716285165, 'Final Portfolio Value': 94199.41470195899}
# INDUSINDBK.NS: {'Total Return': 0.02323622175007589, 'Sharpe Ratio': 0.19623476719638938, 'Max Drawdown': -0.01430811243740382, 'Final Portfolio Value': 102323.6221750076}
# INFY.NS: {'Total Return': -0.08071280983710383, 'Sharpe Ratio': -0.4464324050369367, 'Max Drawdown': -0.08332120673039822, 'Final Portfolio Value': 91928.71901628961}
# ITC.NS: {'Total Return': -0.06481011888858446, 'Sharpe Ratio': -0.38114067388468625, 'Max Drawdown': -0.08461403638571308, 'Final Portfolio Value': 93518.98811114156}
# JSWSTEEL.NS: {'Total Return': -0.0046674551170355905, 'Sharpe Ratio': -0.25104608421304614, 'Max Drawdown': -0.007505804471225952, 'Final Portfolio Value': 99533.25448829644}
# KOTAKBANK.NS: {'Total Return': 0.01265890647669754, 'Sharpe Ratio': 0.15534219931498297, 'Max Drawdown': -0.011865437941619872, 'Final Portfolio Value': 101265.89064766976}
# LT.NS: {'Total Return': 0.13788540373211444, 'Sharpe Ratio': 0.4428860095593556, 'Max Drawdown': -0.007466428610287901, 'Final Portfolio Value': 113788.54037321145}
# LTIM.NS: {'Total Return': -0.011889228310124067, 'Sharpe Ratio': -0.4098373627654287, 'Max Drawdown': -0.011889228310124067, 'Final Portfolio Value': 98811.0771689876}
# M&M.NS: {'Total Return': -0.05938107062616549, 'Sharpe Ratio': -0.3798186171849364, 'Max Drawdown': -0.06326755306904785, 'Final Portfolio Value': 94061.89293738345}
# MARUTI.NS: {'Total Return': 0.025098373657526762, 'Sharpe Ratio': 0.16507243743724945, 'Max Drawdown': -0.03247385309770501, 'Final Portfolio Value': 102509.83736575268}
# NESTLEIND.NS: {'Total Return': -0.03705110412759449, 'Sharpe Ratio': -0.28985840256847734, 'Max Drawdown': -0.049258005752075174, 'Final Portfolio Value': 96294.88958724056}
# NTPC.NS: {'Total Return': -0.14735257084596798, 'Sharpe Ratio': -0.26633073751175323, 'Max Drawdown': -0.1867929938895564, 'Final Portfolio Value': 85264.7429154032}
# ONGC.NS: {'Total Return': -0.07179860165572338, 'Sharpe Ratio': -0.22497888036787794, 'Max Drawdown': -0.10748780111005174, 'Final Portfolio Value': 92820.13983442767}
# POWERGRID.NS: {'Total Return': -0.110485542068116, 'Sharpe Ratio': -0.2547003671267197, 'Max Drawdown': -0.1471116091018474, 'Final Portfolio Value': 88951.4457931884}
# RELIANCE.NS: {'Total Return': 0.055293778023928875, 'Sharpe Ratio': 0.17206912086898646, 'Max Drawdown': -0.0779601259523589, 'Final Portfolio Value': 105529.37780239289}
# SBILIFE.NS: {'Total Return': -0.003093237922757175, 'Sharpe Ratio': -0.6271058939794277, 'Max Drawdown': -0.003243298926049798, 'Final Portfolio Value': 99690.67620772429}
# SHRIRAMFIN.NS: {'Total Return': -0.12225478376372811, 'Sharpe Ratio': -0.3521765329418195, 'Max Drawdown': -0.12804100835473087, 'Final Portfolio Value': 87774.5216236272}
# SBIN.NS: {'Total Return': 0.057739347703106736, 'Sharpe Ratio': 0.22481021151996497, 'Max Drawdown': -0.05273451922565853, 'Final Portfolio Value': 105773.93477031068}
# SUNPHARMA.NS: {'Total Return': 0.006656557983343747, 'Sharpe Ratio': 0.03528070230533172, 'Max Drawdown': -0.08240386093848817, 'Final Portfolio Value': 100665.65579833438}
# TCS.NS: {'Total Return': 0.013652648393183808, 'Sharpe Ratio': 0.2503516357053144, 'Max Drawdown': -0.005520851196151755, 'Final Portfolio Value': 101365.26483931838}
# TATACONSUM.NS: {'Total Return': 0.15855489456632776, 'Sharpe Ratio': 0.3935543481706651, 'Max Drawdown': -0.024959304510490332, 'Final Portfolio Value': 115855.48945663277}
# TATAMOTORS.NS: {'Total Return': -0.07477015021591105, 'Sharpe Ratio': -0.15716651671439652, 'Max Drawdown': -0.12083486812314359, 'Final Portfolio Value': 92522.9849784089}
# TATASTEEL.NS: {'Total Return': -0.09304816035498809, 'Sharpe Ratio': -0.587904009535763, 'Max Drawdown': -0.09304816035498809, 'Final Portfolio Value': 90695.1839645012}
# TECHM.NS: {'Total Return': -0.025666799381432015, 'Sharpe Ratio': -0.2341301568576813, 'Max Drawdown': -0.037011548721725185, 'Final Portfolio Value': 97433.3200618568}
# TITAN.NS: {'Total Return': -0.045763966251263, 'Sharpe Ratio': -0.5412890640868603, 'Max Drawdown': -0.04798359074843106, 'Final Portfolio Value': 95423.6033748737}
# ULTRACEMCO.NS: {'Total Return': 0.04205361235804794, 'Sharpe Ratio': 0.25120232944492, 'Max Drawdown': -0.03110253153552589, 'Final Portfolio Value': 104205.3612358048}
# WIPRO.NS: {'Total Return': 0.010583849198424256, 'Sharpe Ratio': 0.08909082406975292, 'Max Drawdown': -0.022151675133097348, 'Final Portfolio Value': 101058.38491984243}
# ABB.NS: {'Total Return': 0.14394667395017757, 'Sharpe Ratio': 0.30828742925681746, 'Max Drawdown': -0.06388781780531538, 'Final Portfolio Value': 114394.66739501775}
# ADANIENSOL.NS: {'Total Return': -0.028842616755652917, 'Sharpe Ratio': -0.5088474231219775, 'Max Drawdown': -0.052985258057227425, 'Final Portfolio Value': 97115.73832443471}
# ADANIGREEN.NS: {'Total Return': -0.14046494926077435, 'Sharpe Ratio': -0.3503687542083347, 'Max Drawdown': -0.20223218259490217, 'Final Portfolio Value': 85953.50507392257}
# ADANIPOWER.NS: {'Total Return': 0.03205082503709211, 'Sharpe Ratio': 0.09415306981327547, 'Max Drawdown': -0.1185883783006848, 'Final Portfolio Value': 103205.08250370921}
# ATGL.NS: {'Total Return': -0.18543260176445242, 'Sharpe Ratio': -0.5900305943242751, 'Max Drawdown': -0.18543260176445242, 'Final Portfolio Value': 81456.73982355476}
# AMBUJACEM.NS: {'Total Return': -0.06968948745607728, 'Sharpe Ratio': -0.25278867598359117, 'Max Drawdown': -0.07792021924693204, 'Final Portfolio Value': 93031.05125439227}
# BAJAJHLDNG.NS: {'Total Return': -0.016452983016445044, 'Sharpe Ratio': -0.07778023410104998, 'Max Drawdown': -0.041335648854995966, 'Final Portfolio Value': 98354.7016983555}
# BANKBARODA.NS: {'Total Return': -0.10530984036857682, 'Sharpe Ratio': -0.3050410812480997, 'Max Drawdown': -0.14851085514495943, 'Final Portfolio Value': 89469.01596314232}
# BERGEPAINT.NS: {'Total Return': -0.04245556591438604, 'Sharpe Ratio': -0.42190437986039697, 'Max Drawdown': -0.04245556591438615, 'Final Portfolio Value': 95754.44340856139}
# BEL.NS: {'Total Return': 0.004620650562395134, 'Sharpe Ratio': 0.03154615493936381, 'Max Drawdown': -0.032247639938643435, 'Final Portfolio Value': 100462.06505623952}
# BOSCHLTD.NS: {'Total Return': 0.010606465618980598, 'Sharpe Ratio': 0.08133506720887698, 'Max Drawdown': -0.03820470621340588, 'Final Portfolio Value': 101060.64656189806}
# CANBK.NS: {'Total Return': -0.059215894785576095, 'Sharpe Ratio': -0.08650076427295005, 'Max Drawdown': -0.15231960578386927, 'Final Portfolio Value': 94078.41052144239}
# CHOLAFIN.NS: {'Total Return': 0.05469140610836365, 'Sharpe Ratio': 0.19618425282991223, 'Max Drawdown': -0.033212622377395196, 'Final Portfolio Value': 105469.14061083636}
# COLPAL.NS: {'Total Return': 0.04855382659954688, 'Sharpe Ratio': 0.3119423958066922, 'Max Drawdown': -0.004749627929792721, 'Final Portfolio Value': 104855.38265995469}
# DABUR.NS: {'Total Return': -0.08036329047273416, 'Sharpe Ratio': -0.5924245660558057, 'Max Drawdown': -0.08036329047273427, 'Final Portfolio Value': 91963.67095272658}
# DLF.NS: {'Total Return': -0.22522349340978753, 'Sharpe Ratio': -0.41072610704295087, 'Max Drawdown': -0.22522349340978753, 'Final Portfolio Value': 77477.65065902125}
# DMART.NS: {'Total Return': -0.034829491810532964, 'Sharpe Ratio': -0.3434459679110113, 'Max Drawdown': -0.03799570833815347, 'Final Portfolio Value': 96517.05081894671}
# GAIL.NS: {'Total Return': 0.012167204087462524, 'Sharpe Ratio': 0.10441279131140198, 'Max Drawdown': -0.023360203984879147, 'Final Portfolio Value': 101216.72040874626}
# GODREJCP.NS: {'Total Return': 0.04373500380868478, 'Sharpe Ratio': 0.3019226916190078, 'Max Drawdown': -0.0010000000000000009, 'Final Portfolio Value': 104373.50038086849}
# HAVELLS.NS: {'Total Return': 0.022375040772784294, 'Sharpe Ratio': 0.1073552698067888, 'Max Drawdown': -0.04515725467847442, 'Final Portfolio Value': 102237.50407727843}
# HAL.NS: {'Total Return': 0.07584787528030001, 'Sharpe Ratio': 0.29395904555300617, 'Max Drawdown': -0.05337570321216112, 'Final Portfolio Value': 107584.78752803}
# ICICIGI.NS: {'Total Return': 0.015605560588394907, 'Sharpe Ratio': 0.3588704760693881, 'Max Drawdown': -0.0010000000000000009, 'Final Portfolio Value': 101560.55605883949}
# ICICIPRULI.NS: {'Total Return': 0.02869132942744801, 'Sharpe Ratio': 0.20668143778947756, 'Max Drawdown': -0.019962814520417482, 'Final Portfolio Value': 102869.1329427448}
# IOC.NS: {'Total Return': -0.15826775276485938, 'Sharpe Ratio': -0.4024405130445738, 'Max Drawdown': -0.16600751212413156, 'Final Portfolio Value': 84173.22472351407}
# INDIGO.NS: {'Total Return': -0.030939504420633535, 'Sharpe Ratio': -0.09434736636877475, 'Max Drawdown': -0.09497337573979514, 'Final Portfolio Value': 96906.04955793664}
# NAUKRI.NS: {'Total Return': -0.03734733498594578, 'Sharpe Ratio': -0.529233371405202, 'Max Drawdown': -0.03734733498594578, 'Final Portfolio Value': 96265.26650140542}
# IRCTC.NS: {'Total Return': 0.04024380250770143, 'Sharpe Ratio': 0.5321120455258759, 'Max Drawdown': -0.009502082809125678, 'Final Portfolio Value': 104024.38025077015}
# IRFC.NS: {'Total Return': 0.008020041844074344, 'Sharpe Ratio': 0.1538053982576274, 'Max Drawdown': -0.02008043040788332, 'Final Portfolio Value': 100802.00418440743}
# JINDALSTEL.NS: {'Total Return': 0.29903487035742726, 'Sharpe Ratio': 0.5817125299155594, 'Max Drawdown': -0.03284322805164652, 'Final Portfolio Value': 129903.48703574273}
# JIOFIN.NS: {'Total Return': 0.0, 'Sharpe Ratio': nan, 'Max Drawdown': 0.0, 'Final Portfolio Value': 100000.0}
# LICI.NS: {'Total Return': -0.05553156389117886, 'Sharpe Ratio': -0.6717164984836251, 'Max Drawdown': -0.05553156389117886, 'Final Portfolio Value': 94446.84361088212}
# MARICO.NS: {'Total Return': 0.08818362413281533, 'Sharpe Ratio': 0.46769819456539624, 'Max Drawdown': -0.014839091477458655, 'Final Portfolio Value': 108818.36241328153}
# PIDILITIND.NS: {'Total Return': 0.006330923399155086, 'Sharpe Ratio': 0.04012740178891906, 'Max Drawdown': -0.05181524065338583, 'Final Portfolio Value': 100633.09233991551}
# PFC.NS: {'Total Return': 0.05147514400775233, 'Sharpe Ratio': 0.14658210178313305, 'Max Drawdown': -0.04975434599317585, 'Final Portfolio Value': 105147.51440077524}
# PNB.NS: {'Total Return': -0.2792931512973489, 'Sharpe Ratio': -0.5400494408222437, 'Max Drawdown': -0.2792931512973488, 'Final Portfolio Value': 72070.68487026512}
# RECLTD.NS: {'Total Return': -0.12326989725023929, 'Sharpe Ratio': -0.5911155715640761, 'Max Drawdown': -0.12647444540860653, 'Final Portfolio Value': 87673.01027497607}
# MOTHERSON.NS: {'Total Return': -0.04007380785572601, 'Sharpe Ratio': -0.34723774015042513, 'Max Drawdown': -0.04007380785572601, 'Final Portfolio Value': 95992.6192144274}
# SBICARD.NS: {'Total Return': -0.011642236859870425, 'Sharpe Ratio': -0.5173340027966259, 'Max Drawdown': -0.011642236859870425, 'Final Portfolio Value': 98835.77631401295}
# SHREECEM.NS: {'Total Return': -0.014090005834672015, 'Sharpe Ratio': -0.06246508813095972, 'Max Drawdown': -0.03731835014933793, 'Final Portfolio Value': 98590.9994165328}
# SIEMENS.NS: {'Total Return': -0.03858651467974217, 'Sharpe Ratio': -0.19983355469901865, 'Max Drawdown': -0.06232606466188195, 'Final Portfolio Value': 96141.34853202579}
# SRF.NS: {'Total Return': 0.008338385143909832, 'Sharpe Ratio': 0.04230706020579669, 'Max Drawdown': -0.05825833787574353, 'Final Portfolio Value': 100833.83851439098}
# TATAPOWER.NS: {'Total Return': -0.17339681638578752, 'Sharpe Ratio': -0.6554295229427481, 'Max Drawdown': -0.18273426344368182, 'Final Portfolio Value': 82660.31836142125}
# TORNTPHARM.NS: {'Total Return': -0.0734929661070951, 'Sharpe Ratio': -0.2652798127697785, 'Max Drawdown': -0.10953993862036415, 'Final Portfolio Value': 92650.70338929049}
# TRENT.NS: {'Total Return': 0.00887218185213201, 'Sharpe Ratio': 0.0844672612641201, 'Max Drawdown': -0.031048750275082693, 'Final Portfolio Value': 100887.2181852132}
# TVSMOTOR.NS: {'Total Return': 0.0006357322391272735, 'Sharpe Ratio': 0.011932456252133686, 'Max Drawdown': -0.04752854265654072, 'Final Portfolio Value': 100063.57322391272}
# VBL.NS: {'Total Return': -0.03784340005692255, 'Sharpe Ratio': -0.2276189421207148, 'Max Drawdown': -0.054841217538440734, 'Final Portfolio Value': 96215.65999430775}
# VEDL.NS: {'Total Return': 0.07727774090759398, 'Sharpe Ratio': 0.2609583546413273, 'Max Drawdown': -0.03256506994109609, 'Final Portfolio Value': 107727.7740907594}
# ZOMATO.NS: {'Total Return': 0.003988239736831156, 'Sharpe Ratio': 0.051485368532717346, 'Max Drawdown': -0.05048462633672646, 'Final Portfolio Value': 100398.82397368312}
# ZYDUSLIFE.NS: {'Total Return': 0.09676693217350496, 'Sharpe Ratio': 0.4970042594919407, 'Max Drawdown': -0.001000000000000112, 'Final Portfolio Value': 109676.69321735049}
# UNITDSPR.NS: {'Total Return': 0.040717723640337766, 'Sharpe Ratio': 0.3501441700195731, 'Max Drawdown': -0.016275185317889962, 'Final Portfolio Value': 104071.77236403378}
#
# Results for Power Spike:
# ADANIENT.NS: {'Total Return': 0.4310557643412434, 'Sharpe Ratio': 0.2680739306099105, 'Max Drawdown': -0.4574571941384987, 'Final Portfolio Value': 143105.57643412435}
# ADANIPORTS.NS: {'Total Return': -0.5468454768155373, 'Sharpe Ratio': -0.564393608837478, 'Max Drawdown': -0.5501535995897667, 'Final Portfolio Value': 45315.452318446274}
# APOLLOHOSP.NS: {'Total Return': -0.17905695980394698, 'Sharpe Ratio': -0.12967068044465263, 'Max Drawdown': -0.482913322770925, 'Final Portfolio Value': 82094.3040196053}
# ASIANPAINT.NS: {'Total Return': 0.14096333538582617, 'Sharpe Ratio': 0.24055166029683664, 'Max Drawdown': -0.12551092756318982, 'Final Portfolio Value': 114096.33353858262}
# AXISBANK.NS: {'Total Return': 0.08204492614387138, 'Sharpe Ratio': 0.13579457579412568, 'Max Drawdown': -0.16270717841285254, 'Final Portfolio Value': 108204.49261438714}
# BAJAJ-AUTO.NS: {'Total Return': -0.0679719861206477, 'Sharpe Ratio': -0.08127947710468837, 'Max Drawdown': -0.26259380719382375, 'Final Portfolio Value': 93202.80138793524}
# BAJFINANCE.NS: {'Total Return': -0.30267283587038907, 'Sharpe Ratio': -0.3912043689526413, 'Max Drawdown': -0.3307572781691792, 'Final Portfolio Value': 69732.71641296109}
# BAJAJFINSV.NS: {'Total Return': -0.10703965034337504, 'Sharpe Ratio': -0.10453900296900906, 'Max Drawdown': -0.21609736640050503, 'Final Portfolio Value': 89296.03496566249}
# BPCL.NS: {'Total Return': 0.045947213127037756, 'Sharpe Ratio': 0.0919875369240595, 'Max Drawdown': -0.1837548124239573, 'Final Portfolio Value': 104594.72131270377}
# BHARTIARTL.NS: {'Total Return': 0.5212067265005578, 'Sharpe Ratio': 0.5399184365637245, 'Max Drawdown': -0.14043644263871724, 'Final Portfolio Value': 152120.67265005579}
# BRITANNIA.NS: {'Total Return': -0.061201183284318894, 'Sharpe Ratio': -0.06912674455593136, 'Max Drawdown': -0.1985654020677391, 'Final Portfolio Value': 93879.88167156812}
# CIPLA.NS: {'Total Return': -0.21226446575421698, 'Sharpe Ratio': -0.21221501433018058, 'Max Drawdown': -0.3135522437124397, 'Final Portfolio Value': 78773.5534245783}
# COALINDIA.NS: {'Total Return': -0.30751207377233447, 'Sharpe Ratio': -0.3806066761461086, 'Max Drawdown': -0.34373040211627104, 'Final Portfolio Value': 69248.79262276656}
# DIVISLAB.NS: {'Total Return': -0.20660733757943284, 'Sharpe Ratio': -0.18519767753364694, 'Max Drawdown': -0.3190828522371617, 'Final Portfolio Value': 79339.26624205672}
# DRREDDY.NS: {'Total Return': -0.0616284465721787, 'Sharpe Ratio': -0.03413647120427232, 'Max Drawdown': -0.23316678942149227, 'Final Portfolio Value': 93837.15534278213}
# EICHERMOT.NS: {'Total Return': -0.10700314407656564, 'Sharpe Ratio': -0.09144318860322263, 'Max Drawdown': -0.2676040190019362, 'Final Portfolio Value': 89299.68559234343}
# GRASIM.NS: {'Total Return': -0.17335998225077898, 'Sharpe Ratio': -0.2308093922927609, 'Max Drawdown': -0.21369714475415458, 'Final Portfolio Value': 82664.0017749221}
# HCLTECH.NS: {'Total Return': -0.2634663216642247, 'Sharpe Ratio': -0.39807153847354626, 'Max Drawdown': -0.3941486101252486, 'Final Portfolio Value': 73653.36783357753}
# HDFCBANK.NS: {'Total Return': -0.24209236957260205, 'Sharpe Ratio': -0.3998975241521829, 'Max Drawdown': -0.29242293816888587, 'Final Portfolio Value': 75790.7630427398}
# HDFCLIFE.NS: {'Total Return': 0.18060930774027484, 'Sharpe Ratio': 0.35117949111862606, 'Max Drawdown': -0.1473053003885939, 'Final Portfolio Value': 118060.93077402748}
# HEROMOTOCO.NS: {'Total Return': 0.1478155373888308, 'Sharpe Ratio': 0.21955584702426517, 'Max Drawdown': -0.16250778741992078, 'Final Portfolio Value': 114781.55373888309}
# HINDALCO.NS: {'Total Return': -0.23283470567565656, 'Sharpe Ratio': -0.33927812153131737, 'Max Drawdown': -0.2810375975607766, 'Final Portfolio Value': 76716.52943243434}
# HINDUNILVR.NS: {'Total Return': -0.19561838182204783, 'Sharpe Ratio': -0.33306484677565074, 'Max Drawdown': -0.2701557073924836, 'Final Portfolio Value': 80438.16181779522}
# ICICIBANK.NS: {'Total Return': -0.2460526217652076, 'Sharpe Ratio': -0.2503904832586878, 'Max Drawdown': -0.36157102639837546, 'Final Portfolio Value': 75394.73782347924}
# INDUSINDBK.NS: {'Total Return': -0.05851709160239604, 'Sharpe Ratio': 0.043904668599409585, 'Max Drawdown': -0.2925115111013822, 'Final Portfolio Value': 94148.29083976039}
# INFY.NS: {'Total Return': -0.25077328715322944, 'Sharpe Ratio': -0.35860066225429704, 'Max Drawdown': -0.35484920323409985, 'Final Portfolio Value': 74922.67128467705}
# ITC.NS: {'Total Return': 0.1491314392985077, 'Sharpe Ratio': 0.1919090819849986, 'Max Drawdown': -0.15645875208633664, 'Final Portfolio Value': 114913.14392985078}
# JSWSTEEL.NS: {'Total Return': 0.02479979494779494, 'Sharpe Ratio': 0.06921314640863893, 'Max Drawdown': -0.2493011814395545, 'Final Portfolio Value': 102479.97949477949}
# KOTAKBANK.NS: {'Total Return': -0.1192327855386679, 'Sharpe Ratio': -0.12632280540559795, 'Max Drawdown': -0.22450347201825593, 'Final Portfolio Value': 88076.7214461332}
# LT.NS: {'Total Return': 0.10319236227419637, 'Sharpe Ratio': 0.17687866449291023, 'Max Drawdown': -0.11772385826739562, 'Final Portfolio Value': 110319.23622741963}
# LTIM.NS: {'Total Return': 0.051688833282196534, 'Sharpe Ratio': 0.11332813784995699, 'Max Drawdown': -0.27291619006473355, 'Final Portfolio Value': 105168.88332821966}
# M&M.NS: {'Total Return': -0.14897006265547497, 'Sharpe Ratio': -0.1783041313195122, 'Max Drawdown': -0.3182249915122032, 'Final Portfolio Value': 85102.99373445251}
# MARUTI.NS: {'Total Return': 0.0062050077784359114, 'Sharpe Ratio': 0.036753687353802765, 'Max Drawdown': -0.18262436482230016, 'Final Portfolio Value': 100620.5007778436}
# NESTLEIND.NS: {'Total Return': -0.19441251546108318, 'Sharpe Ratio': -0.27955722464752664, 'Max Drawdown': -0.22188684769469513, 'Final Portfolio Value': 80558.74845389168}
# NTPC.NS: {'Total Return': -0.5145003362248315, 'Sharpe Ratio': -0.7081989091325942, 'Max Drawdown': -0.5443842882349514, 'Final Portfolio Value': 48549.96637751685}
# ONGC.NS: {'Total Return': -0.6760798466017073, 'Sharpe Ratio': -0.910748228842576, 'Max Drawdown': -0.7022306737913935, 'Final Portfolio Value': 32392.01533982927}
# POWERGRID.NS: {'Total Return': -0.16111911077733265, 'Sharpe Ratio': -0.16955004655643932, 'Max Drawdown': -0.2140878031217921, 'Final Portfolio Value': 83888.08892226673}
# RELIANCE.NS: {'Total Return': -0.2744140568928759, 'Sharpe Ratio': -0.4737998878507145, 'Max Drawdown': -0.2997876720878848, 'Final Portfolio Value': 72558.5943107124}
# SBILIFE.NS: {'Total Return': -0.22724776006473058, 'Sharpe Ratio': -0.4776847268712275, 'Max Drawdown': -0.30835775546080124, 'Final Portfolio Value': 77275.22399352695}
# SHRIRAMFIN.NS: {'Total Return': -0.12009458334546019, 'Sharpe Ratio': -0.05301461891156869, 'Max Drawdown': -0.4111677265027378, 'Final Portfolio Value': 87990.54166545399}
# SBIN.NS: {'Total Return': 0.35042664706822046, 'Sharpe Ratio': 0.39481385357332816, 'Max Drawdown': -0.17503021460526003, 'Final Portfolio Value': 135042.66470682205}
# SUNPHARMA.NS: {'Total Return': -0.03864153274138726, 'Sharpe Ratio': 0.004785982295058347, 'Max Drawdown': -0.2570701375644334, 'Final Portfolio Value': 96135.84672586128}
# TCS.NS: {'Total Return': -0.2896243211855536, 'Sharpe Ratio': -0.47108209675604734, 'Max Drawdown': -0.33428375045962566, 'Final Portfolio Value': 71037.56788144464}
# TATACONSUM.NS: {'Total Return': 0.1822201599849722, 'Sharpe Ratio': 0.22531195065932108, 'Max Drawdown': -0.24413849534919096, 'Final Portfolio Value': 118222.01599849723}
# TATAMOTORS.NS: {'Total Return': -0.41820193922618165, 'Sharpe Ratio': -0.4448676580538087, 'Max Drawdown': -0.4871959408427219, 'Final Portfolio Value': 58179.806077381836}
# TATASTEEL.NS: {'Total Return': 0.17188221561753791, 'Sharpe Ratio': 0.2512280116550447, 'Max Drawdown': -0.1163900880098725, 'Final Portfolio Value': 117188.22156175379}
# TECHM.NS: {'Total Return': -0.06059222249406526, 'Sharpe Ratio': -0.08439624750028867, 'Max Drawdown': -0.20479100323901023, 'Final Portfolio Value': 93940.77775059348}
# TITAN.NS: {'Total Return': -0.20432246089002648, 'Sharpe Ratio': -0.2611988986646851, 'Max Drawdown': -0.23060119786671185, 'Final Portfolio Value': 79567.75391099736}
# ULTRACEMCO.NS: {'Total Return': -0.1898296371777919, 'Sharpe Ratio': -0.23501927886461982, 'Max Drawdown': -0.27441774107148587, 'Final Portfolio Value': 81017.03628222081}
# WIPRO.NS: {'Total Return': -0.2192603015429545, 'Sharpe Ratio': -0.36313084624029524, 'Max Drawdown': -0.3856898138818605, 'Final Portfolio Value': 78073.96984570455}
# ABB.NS: {'Total Return': 0.45154793316347597, 'Sharpe Ratio': 0.4045227576156283, 'Max Drawdown': -0.14887157936929718, 'Final Portfolio Value': 145154.79331634758}
# ADANIENSOL.NS: {'Total Return': -0.18051965557073058, 'Sharpe Ratio': -0.3974223957707851, 'Max Drawdown': -0.27006814254905354, 'Final Portfolio Value': 81948.03444292695}
# ADANIGREEN.NS: {'Total Return': -0.07483129738612182, 'Sharpe Ratio': 0.03765395308088413, 'Max Drawdown': -0.4542810764268861, 'Final Portfolio Value': 92516.87026138781}
# ADANIPOWER.NS: {'Total Return': 0.07852974828050696, 'Sharpe Ratio': 0.12194563107773031, 'Max Drawdown': -0.30752427965584817, 'Final Portfolio Value': 107852.97482805069}
# ATGL.NS: {'Total Return': 0.7133405442161234, 'Sharpe Ratio': 0.6201543859919372, 'Max Drawdown': -0.27085013788724255, 'Final Portfolio Value': 171334.05442161232}
# AMBUJACEM.NS: {'Total Return': -0.701633615844369, 'Sharpe Ratio': -1.005867394149031, 'Max Drawdown': -0.7121556581116455, 'Final Portfolio Value': 29836.638415563106}
# BAJAJHLDNG.NS: {'Total Return': -0.4943882318248204, 'Sharpe Ratio': -0.604199204192902, 'Max Drawdown': -0.5246663114917981, 'Final Portfolio Value': 50561.17681751796}
# BANKBARODA.NS: {'Total Return': -0.350063165122939, 'Sharpe Ratio': -0.37644269149596177, 'Max Drawdown': -0.4228624102848638, 'Final Portfolio Value': 64993.6834877061}
# BERGEPAINT.NS: {'Total Return': -0.11954029098066665, 'Sharpe Ratio': -0.09971606382242584, 'Max Drawdown': -0.30685684656834844, 'Final Portfolio Value': 88045.97090193334}
# BEL.NS: {'Total Return': -0.2734397479976478, 'Sharpe Ratio': -0.25329548620123193, 'Max Drawdown': -0.37386936271971927, 'Final Portfolio Value': 72656.02520023522}
# BOSCHLTD.NS: {'Total Return': -0.4363196551932428, 'Sharpe Ratio': -0.6344741224801619, 'Max Drawdown': -0.4732018306154675, 'Final Portfolio Value': 56368.03448067572}
# CANBK.NS: {'Total Return': -0.1466815205865134, 'Sharpe Ratio': -0.10395798484730238, 'Max Drawdown': -0.3122604471890148, 'Final Portfolio Value': 85331.84794134866}
# CHOLAFIN.NS: {'Total Return': -0.5506344601255058, 'Sharpe Ratio': -0.6015366057065865, 'Max Drawdown': -0.5965544159080594, 'Final Portfolio Value': 44936.55398744942}
# COLPAL.NS: {'Total Return': -0.1806959860723253, 'Sharpe Ratio': -0.30607186209855014, 'Max Drawdown': -0.30868313477177345, 'Final Portfolio Value': 81930.40139276747}
# DABUR.NS: {'Total Return': -0.3544430407333843, 'Sharpe Ratio': -0.6077617609144943, 'Max Drawdown': -0.38301241409099607, 'Final Portfolio Value': 64555.695926661574}
# DLF.NS: {'Total Return': -0.27622232800838054, 'Sharpe Ratio': -0.25433574707656875, 'Max Drawdown': -0.34875438567443917, 'Final Portfolio Value': 72377.76719916194}
# DMART.NS: {'Total Return': -0.040661379611893755, 'Sharpe Ratio': -0.024490726146033297, 'Max Drawdown': -0.2619087259010482, 'Final Portfolio Value': 95933.86203881062}
# GAIL.NS: {'Total Return': 0.0020113310643889992, 'Sharpe Ratio': 0.041914369421965976, 'Max Drawdown': -0.3071720654058052, 'Final Portfolio Value': 100201.1331064389}
# GODREJCP.NS: {'Total Return': 0.29701287023987, 'Sharpe Ratio': 0.3270784771222895, 'Max Drawdown': -0.27403569788286253, 'Final Portfolio Value': 129701.287023987}
# HAVELLS.NS: {'Total Return': -0.059199436291916374, 'Sharpe Ratio': -0.026621679520438302, 'Max Drawdown': -0.3089160598213633, 'Final Portfolio Value': 94080.05637080836}
# HAL.NS: {'Total Return': -0.20622442336847935, 'Sharpe Ratio': -0.295134402744987, 'Max Drawdown': -0.3681801021678849, 'Final Portfolio Value': 79377.55766315207}
# ICICIGI.NS: {'Total Return': -0.10626541443542092, 'Sharpe Ratio': -0.15534854014405014, 'Max Drawdown': -0.2865968794504258, 'Final Portfolio Value': 89373.4585564579}
# ICICIPRULI.NS: {'Total Return': 0.24611938379783527, 'Sharpe Ratio': 0.3749224829502671, 'Max Drawdown': -0.11885023023119756, 'Final Portfolio Value': 124611.93837978353}
# IOC.NS: {'Total Return': -0.4382715689758787, 'Sharpe Ratio': -0.6090541122534954, 'Max Drawdown': -0.4382715689758787, 'Final Portfolio Value': 56172.84310241213}
# INDIGO.NS: {'Total Return': 0.3972160053442373, 'Sharpe Ratio': 0.40587655928460514, 'Max Drawdown': -0.2003219894891063, 'Final Portfolio Value': 139721.60053442372}
# NAUKRI.NS: {'Total Return': -0.36428271728264294, 'Sharpe Ratio': -0.3290672922411199, 'Max Drawdown': -0.5103201195795181, 'Final Portfolio Value': 63571.72827173571}
# IRCTC.NS: {'Total Return': -0.1336755116594478, 'Sharpe Ratio': -0.16057410512383247, 'Max Drawdown': -0.252500991366329, 'Final Portfolio Value': 86632.44883405522}
# IRFC.NS: {'Total Return': -0.3000758114966656, 'Sharpe Ratio': -0.6747091703547374, 'Max Drawdown': -0.3775661809702975, 'Final Portfolio Value': 69992.41885033344}
# JINDALSTEL.NS: {'Total Return': 0.2931972519590298, 'Sharpe Ratio': 0.2952574672254661, 'Max Drawdown': -0.194069077138729, 'Final Portfolio Value': 129319.72519590298}
# JIOFIN.NS: {'Total Return': -0.017179004315448276, 'Sharpe Ratio': -0.20685370646553206, 'Max Drawdown': -0.07881672659356787, 'Final Portfolio Value': 98282.09956845517}
# LICI.NS: {'Total Return': -0.17833036238070843, 'Sharpe Ratio': -0.7593399250049274, 'Max Drawdown': -0.19820083032603353, 'Final Portfolio Value': 82166.96376192916}
# MARICO.NS: {'Total Return': -0.15324302395890999, 'Sharpe Ratio': -0.15421314862786487, 'Max Drawdown': -0.22801885342171502, 'Final Portfolio Value': 84675.697604109}
# PIDILITIND.NS: {'Total Return': 0.059277960025720944, 'Sharpe Ratio': 0.11352957649800997, 'Max Drawdown': -0.1700405226451095, 'Final Portfolio Value': 105927.7960025721}
# PFC.NS: {'Total Return': -0.08764616607545794, 'Sharpe Ratio': -0.029502986603839647, 'Max Drawdown': -0.29638225965915044, 'Final Portfolio Value': 91235.38339245421}
# PNB.NS: {'Total Return': 0.6358909437069467, 'Sharpe Ratio': 0.34283210015922627, 'Max Drawdown': -0.15285202829839595, 'Final Portfolio Value': 163589.09437069466}
# RECLTD.NS: {'Total Return': -0.3068895276312009, 'Sharpe Ratio': -0.3166432168141586, 'Max Drawdown': -0.34286201697588325, 'Final Portfolio Value': 69311.04723687991}
# MOTHERSON.NS: {'Total Return': 0.21036746484246294, 'Sharpe Ratio': 0.19839205519375674, 'Max Drawdown': -0.4749853022092647, 'Final Portfolio Value': 121036.7464842463}
# SBICARD.NS: {'Total Return': 0.08969092040918647, 'Sharpe Ratio': 0.3284328978526466, 'Max Drawdown': -0.09511539600599739, 'Final Portfolio Value': 108969.09204091865}
# SHREECEM.NS: {'Total Return': -0.10120385532181753, 'Sharpe Ratio': -0.08605543541262954, 'Max Drawdown': -0.2155012190585639, 'Final Portfolio Value': 89879.61446781825}
# SIEMENS.NS: {'Total Return': -0.03608099004549925, 'Sharpe Ratio': -0.0025032414566858504, 'Max Drawdown': -0.2608278888951101, 'Final Portfolio Value': 96391.90099545008}
# SRF.NS: {'Total Return': -0.27412687106570666, 'Sharpe Ratio': -0.2179074025887554, 'Max Drawdown': -0.4461927279553135, 'Final Portfolio Value': 72587.31289342933}
# TATAPOWER.NS: {'Total Return': -0.26642915234229214, 'Sharpe Ratio': -0.28851593038136747, 'Max Drawdown': -0.3764416640101984, 'Final Portfolio Value': 73357.0847657708}
# TORNTPHARM.NS: {'Total Return': -0.364325845650077, 'Sharpe Ratio': -0.3926709761080833, 'Max Drawdown': -0.5077226146711, 'Final Portfolio Value': 63567.415434992305}
# TRENT.NS: {'Total Return': -0.3757068549029402, 'Sharpe Ratio': -0.4178940025559539, 'Max Drawdown': -0.40099711839096563, 'Final Portfolio Value': 62429.31450970598}
# TVSMOTOR.NS: {'Total Return': 0.2476226123752694, 'Sharpe Ratio': 0.2623544154068421, 'Max Drawdown': -0.3381822012177548, 'Final Portfolio Value': 124762.26123752694}
# VBL.NS: {'Total Return': -0.31336200893256916, 'Sharpe Ratio': -0.378928277189287, 'Max Drawdown': -0.32539476595566375, 'Final Portfolio Value': 68663.79910674308}
# VEDL.NS: {'Total Return': -0.022430566978575928, 'Sharpe Ratio': 0.03741264015610411, 'Max Drawdown': -0.352024018763025, 'Final Portfolio Value': 97756.9433021424}
# ZOMATO.NS: {'Total Return': -0.19536783924456647, 'Sharpe Ratio': -0.31929213571555265, 'Max Drawdown': -0.4078828115722384, 'Final Portfolio Value': 80463.21607554336}
# ZYDUSLIFE.NS: {'Total Return': -0.03521820192381664, 'Sharpe Ratio': 0.00975481174606137, 'Max Drawdown': -0.2590958286852666, 'Final Portfolio Value': 96478.17980761833}
# UNITDSPR.NS: {'Total Return': 0.06439894632754517, 'Sharpe Ratio': 0.1077272419815818, 'Max Drawdown': -0.23330882518380858, 'Final Portfolio Value': 106439.89463275451}
#
# Results DataFrame:
#                       Coiled Spring NR7                              \
#                             ADANIENT.NS ADANIPORTS.NS APOLLOHOSP.NS
# Total Return                  -0.103716     -0.138619     -0.084992
# Sharpe Ratio                  -0.186508     -0.290904     -0.229411
# Max Drawdown                  -0.177423     -0.176236     -0.108653
# Final Portfolio Value      89628.426818  86138.149795  91500.839176
#
#                                                                   \
#                       ASIANPAINT.NS   AXISBANK.NS  BAJAJ-AUTO.NS
# Total Return              -0.154000     -0.270690       0.011678
# Sharpe Ratio              -0.434900     -0.764158       0.059397
# Max Drawdown              -0.175145     -0.297588      -0.053212
# Final Portfolio Value  84600.027941  72931.003287  101167.786228
#
#                                                                                \
#                       BAJFINANCE.NS BAJAJFINSV.NS       BPCL.NS BHARTIARTL.NS
# Total Return              -0.272608     -0.047720     -0.051405     -0.196732
# Sharpe Ratio              -0.681549     -0.086847     -0.120636     -0.646510
# Max Drawdown              -0.287823     -0.161338     -0.087196     -0.201356
# Final Portfolio Value  72739.184477  95228.030363  94859.463566  80326.782359
#
#                        ...   Power Spike                              \
#                        ...        SRF.NS  TATAPOWER.NS TORNTPHARM.NS
# Total Return           ...     -0.274127     -0.266429     -0.364326
# Sharpe Ratio           ...     -0.217907     -0.288516     -0.392671
# Max Drawdown           ...     -0.446193     -0.376442     -0.507723
# Final Portfolio Value  ...  72587.312893  73357.084766  63567.415435
#
#                                                                   \
#                            TRENT.NS    TVSMOTOR.NS        VBL.NS
# Total Return              -0.375707       0.247623     -0.313362
# Sharpe Ratio              -0.417894       0.262354     -0.378928
# Max Drawdown              -0.400997      -0.338182     -0.325395
# Final Portfolio Value  62429.314510  124762.261238  68663.799107
#
#
#                             VEDL.NS     ZOMATO.NS  ZYDUSLIFE.NS    UNITDSPR.NS
# Total Return              -0.022431     -0.195368     -0.035218       0.064399
# Sharpe Ratio               0.037413     -0.319292      0.009755       0.107727
# Max Drawdown              -0.352024     -0.407883     -0.259096      -0.233309
# Final Portfolio Value  97756.943302  80463.216076  96478.179808  106439.894633
#
# [4 rows x 300 columns]

# %%
results_df.columns
# Out:
# MultiIndex([('Coiled Spring NR7',   'ADANIENT.NS'),
#             ('Coiled Spring NR7', 'ADANIPORTS.NS'),
#             ('Coiled Spring NR7', 'APOLLOHOSP.NS'),
#             ('Coiled Spring NR7', 'ASIANPAINT.NS'),
#             ('Coiled Spring NR7',   'AXISBANK.NS'),
#             ('Coiled Spring NR7', 'BAJAJ-AUTO.NS'),
#             ('Coiled Spring NR7', 'BAJFINANCE.NS'),
#             ('Coiled Spring NR7', 'BAJAJFINSV.NS'),
#             ('Coiled Spring NR7',       'BPCL.NS'),
#             ('Coiled Spring NR7', 'BHARTIARTL.NS'),
#             ...
#             (      'Power Spike',        'SRF.NS'),
#             (      'Power Spike',  'TATAPOWER.NS'),
#             (      'Power Spike', 'TORNTPHARM.NS'),
#             (      'Power Spike',      'TRENT.NS'),
#             (      'Power Spike',   'TVSMOTOR.NS'),
#             (      'Power Spike',        'VBL.NS'),
#             (      'Power Spike',       'VEDL.NS'),
#             (      'Power Spike',     'ZOMATO.NS'),
#             (      'Power Spike',  'ZYDUSLIFE.NS'),
#             (      'Power Spike',   'UNITDSPR.NS')],
#            length=300)

# %%
coiled_spring_nr7_results_df = pd.DataFrame(results_df['Coiled Spring NR7'])
coiled_spring_nr7_results_df.to_csv('coiled_spring_nr7_results_df.csv')

finger_finder_results_df = pd.DataFrame(results_df['Finger Finder'])
finger_finder_results_df.to_csv('finger_finder_results_df.csv')

power_spike_results_df = pd.DataFrame(results_df['Power Spike'])
power_spike_results_df.to_csv('power_spike_results_df.csv')

# %%
coiled_spring_nr7_results_df
# Out:
#                         ADANIENT.NS  ADANIPORTS.NS  APOLLOHOSP.NS  \
# Total Return              -0.103716      -0.138619      -0.084992
# Sharpe Ratio              -0.186508      -0.290904      -0.229411
# Max Drawdown              -0.177423      -0.176236      -0.108653
# Final Portfolio Value  89628.426818   86138.149795   91500.839176
#
#                        ASIANPAINT.NS   AXISBANK.NS  BAJAJ-AUTO.NS  \
# Total Return               -0.154000     -0.270690       0.011678
# Sharpe Ratio               -0.434900     -0.764158       0.059397
# Max Drawdown               -0.175145     -0.297588      -0.053212
# Final Portfolio Value   84600.027941  72931.003287  101167.786228
#
#                        BAJFINANCE.NS  BAJAJFINSV.NS       BPCL.NS  \
# Total Return               -0.272608      -0.047720     -0.051405
# Sharpe Ratio               -0.681549      -0.086847     -0.120636
# Max Drawdown               -0.287823      -0.161338     -0.087196
# Final Portfolio Value   72739.184477   95228.030363  94859.463566
#
#                        BHARTIARTL.NS  ...        SRF.NS  TATAPOWER.NS  \
# Total Return               -0.196732  ...     -0.127117     -0.083827
# Sharpe Ratio               -0.646510  ...     -0.334972     -0.227889
# Max Drawdown               -0.201356  ...     -0.181869     -0.124286
# Final Portfolio Value   80326.782359  ...  87288.298325  91617.281128
#
#                        TORNTPHARM.NS      TRENT.NS   TVSMOTOR.NS  \
# Total Return               -0.160278     -0.139862     -0.159567
# Sharpe Ratio               -0.491054     -0.313672     -0.256735
# Max Drawdown               -0.192114     -0.165212     -0.170475
# Final Portfolio Value   83972.228005  86013.817057  84043.261288
#
#                              VBL.NS       VEDL.NS      ZOMATO.NS  \
# Total Return              -0.051838     -0.289966       0.111574
# Sharpe Ratio              -0.084526     -0.603191       0.393804
# Max Drawdown              -0.213059     -0.295260      -0.068821
# Final Portfolio Value  94816.196410  71003.443237  111157.428461
#
#                        ZYDUSLIFE.NS   UNITDSPR.NS
# Total Return              -0.138408     -0.094390
# Sharpe Ratio              -0.514436     -0.231212
# Max Drawdown              -0.163458     -0.154371
# Final Portfolio Value  86159.153656  90561.015210
#
# [4 rows x 100 columns]

# %%
finger_finder_results_df
# Out:
#                          ADANIENT.NS  ADANIPORTS.NS  APOLLOHOSP.NS  \
# Total Return                0.065314      -0.157168       0.050432
# Sharpe Ratio                0.240577      -0.430737       0.235183
# Max Drawdown               -0.033912      -0.189119      -0.037431
# Final Portfolio Value  106531.449661   84283.231547  105043.168866
#
#                        ASIANPAINT.NS    AXISBANK.NS  BAJAJ-AUTO.NS  \
# Total Return                0.073819       0.030143       0.051173
# Sharpe Ratio                0.293931       0.167282       0.290830
# Max Drawdown               -0.002738      -0.043532      -0.008851
# Final Portfolio Value  107381.880459  103014.251277  105117.261931
#
#                        BAJFINANCE.NS  BAJAJFINSV.NS        BPCL.NS  \
# Total Return               -0.033129      -0.011161       0.039228
# Sharpe Ratio               -0.068259      -0.024686       0.212923
# Max Drawdown               -0.119961      -0.046567      -0.024021
# Final Portfolio Value   96687.079285   98883.877060  103922.768055
#
#                        BHARTIARTL.NS  ...         SRF.NS  TATAPOWER.NS  \
# Total Return                0.011771  ...       0.008338     -0.173397
# Sharpe Ratio                0.051559  ...       0.042307     -0.655430
# Max Drawdown               -0.069603  ...      -0.058258     -0.182734
# Final Portfolio Value  101177.086610  ...  100833.838514  82660.318361
#
#                        TORNTPHARM.NS       TRENT.NS    TVSMOTOR.NS  \
# Total Return               -0.073493       0.008872       0.000636
# Sharpe Ratio               -0.265280       0.084467       0.011932
# Max Drawdown               -0.109540      -0.031049      -0.047529
# Final Portfolio Value   92650.703389  100887.218185  100063.573224
#
#                              VBL.NS        VEDL.NS      ZOMATO.NS  \
# Total Return              -0.037843       0.077278       0.003988
# Sharpe Ratio              -0.227619       0.260958       0.051485
# Max Drawdown              -0.054841      -0.032565      -0.050485
# Final Portfolio Value  96215.659994  107727.774091  100398.823974
#
#                         ZYDUSLIFE.NS    UNITDSPR.NS
# Total Return                0.096767       0.040718
# Sharpe Ratio                0.497004       0.350144
# Max Drawdown               -0.001000      -0.016275
# Final Portfolio Value  109676.693217  104071.772364
#
# [4 rows x 100 columns]

# %%
power_spike_results_df
# Out:
#                          ADANIENT.NS  ADANIPORTS.NS  APOLLOHOSP.NS  \
# Total Return                0.431056      -0.546845      -0.179057
# Sharpe Ratio                0.268074      -0.564394      -0.129671
# Max Drawdown               -0.457457      -0.550154      -0.482913
# Final Portfolio Value  143105.576434   45315.452318   82094.304020
#
#                        ASIANPAINT.NS    AXISBANK.NS  BAJAJ-AUTO.NS  \
# Total Return                0.140963       0.082045      -0.067972
# Sharpe Ratio                0.240552       0.135795      -0.081279
# Max Drawdown               -0.125511      -0.162707      -0.262594
# Final Portfolio Value  114096.333539  108204.492614   93202.801388
#
#                        BAJFINANCE.NS  BAJAJFINSV.NS        BPCL.NS  \
# Total Return               -0.302673      -0.107040       0.045947
# Sharpe Ratio               -0.391204      -0.104539       0.091988
# Max Drawdown               -0.330757      -0.216097      -0.183755
# Final Portfolio Value   69732.716413   89296.034966  104594.721313
#
#                        BHARTIARTL.NS  ...        SRF.NS  TATAPOWER.NS  \
# Total Return                0.521207  ...     -0.274127     -0.266429
# Sharpe Ratio                0.539918  ...     -0.217907     -0.288516
# Max Drawdown               -0.140436  ...     -0.446193     -0.376442
# Final Portfolio Value  152120.672650  ...  72587.312893  73357.084766
#
#                        TORNTPHARM.NS      TRENT.NS    TVSMOTOR.NS  \
# Total Return               -0.364326     -0.375707       0.247623
# Sharpe Ratio               -0.392671     -0.417894       0.262354
# Max Drawdown               -0.507723     -0.400997      -0.338182
# Final Portfolio Value   63567.415435  62429.314510  124762.261238
#
#                              VBL.NS       VEDL.NS     ZOMATO.NS  ZYDUSLIFE.NS  \
# Total Return              -0.313362     -0.022431     -0.195368     -0.035218
# Sharpe Ratio              -0.378928      0.037413     -0.319292      0.009755
# Max Drawdown              -0.325395     -0.352024     -0.407883     -0.259096
# Final Portfolio Value  68663.799107  97756.943302  80463.216076  96478.179808
#
#                          UNITDSPR.NS
# Total Return                0.064399
# Sharpe Ratio                0.107727
# Max Drawdown               -0.233309
# Final Portfolio Value  106439.894633
#
# [4 rows x 100 columns]
